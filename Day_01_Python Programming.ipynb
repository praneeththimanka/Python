# %%
# Python Programming

# %% [markdown]
# print( "Hello Sri Lanka")
#
# print ("Hello Colombo")
# print("How are you?")

# %%
print("Hello Girl")
# Out:
# Hello Girl

# %%
print("Welcome to Python World")
# Out:
# Welcome to Python World

# %%
print('Hello guys')
# Out:
# Hello guys

# %% [markdown]
# # Level 1

# %% [markdown]
# ## Level 2

# %% [markdown]
# ### Level 3

# %% [markdown]
# print( "Hello Sri Lanka")
# print ("Hello Colombo")
# print("How are you?")
# print( "Hello Sri Lanka") print ("Hello Colombo")
# print("How are you?")
# ### this message written by Me (Praneeth) initiated by Mr. Senaka

# %% [markdown]
# # Python Programming

# %% [markdown]
# ## Day 01

# %%
print("My Name is Praneeth Thimanka")
print("I am working at Commercial Bank")
print("And I Live in Wattala")
print("Currently I am learning Python Programming at IIT")
# Out:
# My Name is Praneeth Thimanka
# I am working at Commercial Bank
# And I Live in Wattala
# Currently I am learning Python Programming at IIT

# %% [markdown]
# ### This typo was done by me(Praneeth) on June 27, 2026.
