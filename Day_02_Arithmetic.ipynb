# %%
5+2
# Out:
# 7

# %%
5-2
# Out:
# 3

# %%
5*2
# Out:
# 10

# %%
5/2
# Out:
# 2.5

# %%
5//2
# Out:
# 2

# %%
5%2
# Out:
# 1

# %%
5**2
# Out:
# 25

# %%
(5+3)*2**2-10/5+7%3
# Out:
# 31.0

# %%
5//10
# Out:
# 0

# %%
5%10
# Out:
# 5
