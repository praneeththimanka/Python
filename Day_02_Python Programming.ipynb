# %%
print("Day 02")
# Out:
# Day 02

# %%
print("Hello IIT")
# Out:
# Hello IIT

# %%
print("Hello Python")
# Out:
# Hello Python

# %%
print("Second day of the python class")
# Out:
# Second day of the python class
