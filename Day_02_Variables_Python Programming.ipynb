# %%
name="Praneeth"

# %%
age=25

# %%
height=6.1

# %%
print(name)
# Out:
# Praneeth

# %%
print(age)
# Out:
# 25

# %%
print(height)
# Out:
# 6.1

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
print(type(height))
# Out:
# <class 'float'>

# %%
print(type(name))
print(type(age))
print(type(height))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
my_name=input("What is your name?")
print(my_name)
# Out:
# What is your name? Praneeth
# Praneeth

# %%
print(my_name)
# Out:
# Praneeth

# %%
my_profession=input("What is your Proffesion?")
# Out:
# What is your Proffesion? Banker

# %%
print(my_profession)
# Out:
# Banker

# %%
number1=input("Enter the first number")
number2=input("Enter the second number")
print(number1)
print(number2)
print(type(number1))
print(type(number2))
# Out:
# Enter the first number 100
# Enter the second number 200
# 100
# 200
# <class 'str'>
# <class 'str'>

# %%
number1=int(input("Enter the first number"))
number2=input("Enter the second number")
print(number1)
print(number2)
print(type(number1))
print(type(number2))
# Out:
# Enter the first number 100
# Enter the second number 200
# 100
# 200
# <class 'int'>
# <class 'str'>

# %%
pet_name=input("What is your Pet name?")
home_town=input("What is your Home town?")
Dream_job=input("What is your Dream Job?")
# Out:
# What is your Pet name? Sandy
# What is your Home town? Pannipitiya
# What is your Dream Job? Sportsman

# %%
birth_year=int(input("What is your birth year?"))
print(type(birth_year))
# Out:
# What is your birth year? 1987
# <class 'int'>

# %%
martial_status=bool(input("Are you married?"))
print(type(martial_status))
# Out:
# Are you married? Yes
# <class 'bool'>

# %%
tea_price=float(input("What is the price of a cup of tea?"))
print(type(tea_price))
# Out:
# What is the price of a cup of tea? 15.50
# <class 'float'>

# %%
item_name=str(input("What is there for lunch?"))
quantity_available=int(input("How much is a lunch packet?"))
print(type(item_name))
print(type(quantity_available))
# Out:
# What is there for lunch? Rice and Curry
# How much is a lunch packet? 500
# <class 'str'>
# <class 'int'>
