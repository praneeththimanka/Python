# %%
age=int(input("Enter the Age?"))
if age>18:
    print("Adult")
else:
    print("Minor")
# Out:
# Enter the Age? 4
# Minor

# %%
marks=int(input("Enter the Marks"))
if  marks>50:
          print("Pass")
else:
    print("Fail")
# Out:
# Enter the Marks 35
# Fail

# %%
marks=int(input("Enter the Marks"))
if  marks>=75:
          print("A Grade")
elif marks>=65:
    print("B Grade")
elif marks>=50:
    print("C Grade")
else:
    print("Fail")
# Out:
# Enter the Marks 55
# C Grade

# %%
number=int(input("Enter the number"))
if  number>0:
          print("Positive")
elif number==0:
    print("Zero")
elif number<0:
    print("Negative")
# Out:
# Enter the number -12
# Negative

# %%
number=int(input("Enter the number"))
if number%2==0:
    print("Even Number")
else :
    print("Odd Number")
# Out:
# Enter the number 4
# Even Number

# %%
Name=str(input("Enter the student Name"))
marks=int(input("Enter the Marks"))
if  marks>=75:
          print("Excellent,", Name, "You have A Grade")
elif marks>=65:
    print("Great,", Name, "You have B Grade")
elif marks>=50:
    print("Good,", Name, "You have C Grade")
else:
    print("Fail")
# Out:
# Enter the student Name Charith
# Enter the Marks 55
# Good, Charith You have C Grade

# %%
score=int(input("Enter the score (0-100)"))

if  score>=90:
          print("Excellent,", "You have A Grade")
elif score>80 and score<=89:
    print("Great,", "You have B Grade")
elif score>70 and score<=79:
    print("Very Good,", "You have C Grade")
elif score>60 and score<=69:
    print("Good,", "You have D Grade")
elif marks<60:
    print("Not Good,", "You have D Grade")
else:
    print("Invalid Score Entered")
# Out:
# Enter the score (0-100) 92
# Excellent, You have A Grade

# %%
number1=int(input("Enter the first number"))
number2=int(input("Enter the second number"))
sum=number1+number2
print(sum)
# Out:
# Enter the first number 87
# Enter the second number 89
# 176

# %%
first_name=str(input("Enter the first name"))
second_name=str(input("Enter the second name"))
print(first_name,second_name)
# Out:
# Enter the first name Praneeth
# Enter the second name Thimanka
# Praneeth Thimanka

# %%
first_name=str(input("Enter the first name"))
second_name=str(input("Enter the second name"))
print(first_name," ",second_name)
# Out:
# Enter the first name Praneeth
# Enter the second name Thimanka
# Praneeth   Thimanka

# %%
first_name=str(input("Enter the first name"))
second_name=str(input("Enter the second name"))
age=input("Enter the age")
print(f"My first name is {first_name} my second name is {second_name} my age is {age}")
# Out:
# Enter the first name Praneeth
# Enter the second name Thimanka
# Enter the age 38
# My first name is Praneeth my second name is Thimanka my age is 38

# %%
print("hello/nare")
# Out:
# hello/nare

# %%
Name="Hello Sri Lanka"
print(Name[6], Name[10])
# Out:
# S L

# %%
Name="Hello Sri Lanka"
print(Name[1:10])
# Out:
# ello Sri

# %%
Name="Hello Sri Lanka"
print(Name.[upper])
# Out:
#   Cell In[69], line 2
#     print(Name.[upper])
#                ^
# SyntaxError: invalid syntax
