# %%
correct_password="abc123"
password = input("Enter Password")
while password!=correct_password:
    print("Incorrect Password.Try Again.")
    password=input("Enter Password: ")
print("Access granted!")
# Out:
# Enter Password 222333
# Incorrect Password.Try Again.
# Enter Password:  555333
# Incorrect Password.Try Again.
# Enter Password:  666555
# Incorrect Password.Try Again.
# Enter Password:  111555
# Incorrect Password.Try Again.
# Enter Password:  abc123
# Access granted!

# %%
while True:
    command=input("Type 'exit' to quit:")
    if command == "Exit":
        break
# Out:
# Type 'exit' to quit: exite
# Type 'exit' to quit: exits
# Type 'exit' to quit: exit
# Type 'exit' to quit: Exit

# %%
age=-1
while age <=0:
    age=int(input("Enter a valid age:"))
print("Thank you!")
# Out:
# Enter a valid age: -5
# Enter a valid age: -4
# Enter a valid age: 0
# Enter a valid age: 5
# Thank you!

# %%
choice=""
while choice!="3":
    print("1.Add\n2.View\n3.Exit")
    choice=input("Choose an option:")
print("Good Bye")
# Out:
# 1.Add
# 2.View
# 3.Exit
# Choose an option: 1
# 1.Add
# 2.View
# 3.Exit
# Choose an option: 2
# 1.Add
# 2.View
# 3.Exit
# Choose an option: 3
# Good Bye

# %%
N=1
total=0
for i in range(1,N+1):
    total+=1
print("Sum:",total)
# Out:
# Sum: 1

# %%
for i in range(1,6):
    print("@"*i)
# Out:
# @
# @@
# @@@
# @@@@
# @@@@@

# %%
for i in range(2):
    for j in range(3):
        print(i,j)
# Out:
# 0 0
# 0 1
# 0 2
# 1 0
# 1 1
# 1 2

# %%
for i in range(1,4):
    for j in range(i):
        print("*",end="")
    print()
# Out:
# *
# **
# ***

# %%
count=5
while count >0:
    print(count,end="")
    count-=2
# Out:
# 531

# %%
for i in range(1,11):
